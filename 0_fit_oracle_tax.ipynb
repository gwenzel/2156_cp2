# %%
# Setup and Data Loading
import numpy as np
import warnings
import os
warnings.filterwarnings('ignore')

# Clone repository if not exists and load data
if not os.path.exists('2155-Challenge-Problem-2'):
    import subprocess
    print("Cloning repository...")
    subprocess.run(['git', 'clone', 'https://github.com/Lyleregenwetter/2155-Challenge-Problem-2'], 
                   check=True, cwd='.')
    print("Repository cloned!")

# Change to the repository directory and load data
os.chdir('2155-Challenge-Problem-2')

# Import utilities
from utils_public import load_grids, plot_n_grids

print("Loading data...")
grids = load_grids()
ratings = np.load("datasets/scores.npy")

print(f"Grids shape: {grids.shape}")
print(f"Ratings shape: {ratings.shape}")
print(f"Available ratings per advisor: {(~np.isnan(ratings)).sum(axis=0)}")

# advisor_names = ["Wellness", "Tax", "Transportation", "Business"]

# Change back to parent directory for saving results
os.chdir('..')
# Out:
# Loading data...
# Grids shape: (500000, 7, 7)
# Ratings shape: (500000, 4)
# Available ratings per advisor: [5000 5000 5000 5000]

# %%
# Reload the oracle module to get the latest changes
import importlib
import sys
if 'oracle' in sys.modules:
    importlib.reload(sys.modules['oracle'])
from oracle import CNNTaxOracle # TaxOracle

# Initialize Tax Oracle
tax_oracle = CNNTaxOracle()
print("Tax Oracle initialized!")

# Select grids and ratings for Tax advisor (not nan, index 1)
tax_index = 1
grids_subset = grids[~np.isnan(ratings[:, tax_index])]
ratings_subset = ratings[~np.isnan(ratings[:, tax_index]), tax_index]

# Get model scores
model_scores, train_data, test_data = tax_oracle.fit_model(grids_subset, ratings_subset)
print("Model Scores:", model_scores)

predictions = tax_oracle.predict(grids_subset)
print("Predictions shape:", predictions.shape)
# Out:
# 🔥 PyTorch available, using device: cpu
# Tax Oracle initialized!
#
# ============================================================
# Training PyTorch CNN Transportation Oracle
# ============================================================
# Available training samples: 5000
# Training parameters:
#   - Epochs: 250
#   - Batch size: 128
#   - Test size: 0.2
#   - Learning rate: 0.0003
#   - Model type: auto
#   - Device: cpu
# 🔥 Using PyTorch CNN approach for spatial pattern recognition...
# 🤖 Auto-selected model type: standard (advisor_id: 1)
# 🎭 Training ensemble with seeds: [42, 43, 44]
#
# 🌱 Training model 1/3 with seed 42
# 🏗️ CNN Architecture:
# CityCNN1(
#   (block1): Sequential(
#     (0): Conv2d(5, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (block2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (gap): AdaptiveAvgPool2d(output_size=1)
#   (head): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# 📊 Using weighted MSE loss with gamma=0.75
#   Epoch   1: Train Loss = 0.081597, Val Loss = 0.059546, LR = 3.00e-04
#   Epoch  10: Train Loss = 0.018858, Val Loss = 0.015477, LR = 1.50e-04
#   Epoch  20: Train Loss = 0.015073, Val Loss = 0.007065, LR = 1.50e-04
#   Epoch  30: Train Loss = 0.012500, Val Loss = 0.005809, LR = 3.75e-05
#   Epoch  40: Train Loss = 0.012593, Val Loss = 0.005066, LR = 3.75e-05
#   Epoch  50: Train Loss = 0.011598, Val Loss = 0.004974, LR = 1.87e-05
#   Epoch  60: Train Loss = 0.011201, Val Loss = 0.005047, LR = 1.87e-05
#   Epoch  70: Train Loss = 0.011468, Val Loss = 0.005260, LR = 4.69e-06
#   Epoch  80: Train Loss = 0.011369, Val Loss = 0.005057, LR = 2.34e-06
#   Epoch  90: Train Loss = 0.010823, Val Loss = 0.005099, LR = 5.86e-07
#   Epoch 100: Train Loss = 0.010842, Val Loss = 0.004962, LR = 1.46e-07
# Early stopping at epoch 102
#
# 🌱 Training model 2/3 with seed 43
# 📊 Using weighted MSE loss with gamma=0.75
#   Epoch   1: Train Loss = 0.135923, Val Loss = 0.058431, LR = 3.00e-04
#   Epoch  10: Train Loss = 0.021652, Val Loss = 0.008582, LR = 3.00e-04
#   Epoch  20: Train Loss = 0.016021, Val Loss = 0.009268, LR = 3.00e-04
#   Epoch  30: Train Loss = 0.012228, Val Loss = 0.005701, LR = 1.50e-04
#   Epoch  40: Train Loss = 0.011887, Val Loss = 0.004916, LR = 1.50e-04
#   Epoch  50: Train Loss = 0.011079, Val Loss = 0.005729, LR = 1.50e-04
#   Epoch  60: Train Loss = 0.009912, Val Loss = 0.004123, LR = 7.50e-05
#   Epoch  70: Train Loss = 0.009648, Val Loss = 0.004258, LR = 3.75e-05
#   Epoch  80: Train Loss = 0.009142, Val Loss = 0.003682, LR = 1.87e-05
#   Epoch  90: Train Loss = 0.009268, Val Loss = 0.003583, LR = 9.37e-06
#   Epoch 100: Train Loss = 0.009197, Val Loss = 0.003513, LR = 2.34e-06
#   Epoch 110: Train Loss = 0.009470, Val Loss = 0.003557, LR = 1.17e-06
#   Epoch 120: Train Loss = 0.008932, Val Loss = 0.003471, LR = 5.86e-07
#   Epoch 130: Train Loss = 0.010296, Val Loss = 0.003433, LR = 1.46e-07
# Early stopping at epoch 132
#
# 🌱 Training model 3/3 with seed 44
# 📊 Using weighted MSE loss with gamma=0.75
#   Epoch   1: Train Loss = 0.112194, Val Loss = 0.052703, LR = 3.00e-04
#   Epoch  10: Train Loss = 0.017912, Val Loss = 0.013749, LR = 3.00e-04
#   Epoch  20: Train Loss = 0.012836, Val Loss = 0.007789, LR = 3.00e-04
#   Epoch  30: Train Loss = 0.011388, Val Loss = 0.004482, LR = 1.50e-04
#   Epoch  40: Train Loss = 0.009870, Val Loss = 0.003580, LR = 7.50e-05
#   Epoch  50: Train Loss = 0.008901, Val Loss = 0.003630, LR = 1.87e-05
#   Epoch  60: Train Loss = 0.009031, Val Loss = 0.003532, LR = 9.37e-06
#   Epoch  70: Train Loss = 0.008435, Val Loss = 0.003336, LR = 9.37e-06
#   Epoch  80: Train Loss = 0.008712, Val Loss = 0.003570, LR = 2.34e-06
# Early stopping at epoch 89
#
# 🎯 Averaging ensemble predictions...
#
# 📊 PyTorch CNN Performance:
#    Training R²: 0.9825
#    Test R²: 0.9720
# Model Scores: 0.9719560947261621
# Creating predictions for 5000 grids...
# 🎭 Using ensemble of 3 models...
# Predictions shape: (5000,)

# %%
from sklearn.model_selection import train_test_split
from oracle import plot_and_r2

# For PyTorch CNN model, we need to recreate the train/test split and get predictions
# Use the same random state as used in the model training (42)
X_train, X_test, y_train, y_test = train_test_split(
    grids_subset, ratings_subset, test_size=0.2, random_state=42)

print("Making predictions on train set...")
preds_train = tax_oracle.predict(X_train)

print("Making predictions on test set...")
preds_test = tax_oracle.predict(X_test)

# Create the plot and get R² scores
train_r2, test_r2 = plot_and_r2(preds_train, preds_test, y_train, y_test, name="Tax")

# Additional analysis
print(f"\nModel Performance Summary:")
print(f"{'='*40}")
print(f"Training R²:   {train_r2:.4f}")
print(f"Test R²:       {test_r2:.4f}")
print(f"Overfitting:   {'Yes' if (train_r2 - test_r2) > 0.1 else 'No'} ({train_r2 - test_r2:.4f})")
print(f"Performance:   {'Excellent' if test_r2 > 0.9 else 'Good' if test_r2 > 0.8 else 'Fair' if test_r2 > 0.6 else 'Poor'}")
# Out:
# Making predictions on train set...
# Creating predictions for 4000 grids...
# 🎭 Using ensemble of 3 models...
# Making predictions on test set...
# Creating predictions for 1000 grids...
# 🎭 Using ensemble of 3 models...
# Tax Oracle Train Set R² score: 0.9825
# Tax Oracle Test Set R² score: 0.9720
#
# Model Performance Summary:
# ========================================
# Training R²:   0.9825
# Test R²:       0.9720
# Overfitting:   No (0.0106)
# Performance:   Excellent

# %%
# save model in pkl file
tax_oracle.save_model('data/models/tax_oracle_model.pkl')

# --- IGNORE ---
# instructions on how to use exported model
# from oracle import BusinessOracle
# business_oracle = BusinessOracle.load_model("business_oracle_model.pkl")
# --- IGNORE ---
# Out:
# 💾 Saved PyTorch model to tax_oracle_model_pytorch.pth and metadata to tax_oracle_model.pkl
