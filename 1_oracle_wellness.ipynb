# %%
# Setup and Data Loading
import numpy as np
import warnings
import os
warnings.filterwarnings('ignore')

# Clone repository if not exists and load data
if not os.path.exists('2155-Challenge-Problem-2'):
    import subprocess
    print("Cloning repository...")
    subprocess.run(['git', 'clone', 'https://github.com/Lyleregenwetter/2155-Challenge-Problem-2'], 
                   check=True, cwd='.')
    print("Repository cloned!")

# Change to the repository directory and load data
os.chdir('2155-Challenge-Problem-2')

# Import utilities
from utils_public import load_grids, plot_n_grids

print("Loading data...")
grids = load_grids()
ratings = np.load("datasets/scores.npy")

print(f"Grids shape: {grids.shape}")
print(f"Ratings shape: {ratings.shape}")
print(f"Available ratings per advisor: {(~np.isnan(ratings)).sum(axis=0)}")

# advisor_names = ["Wellness", "Tax", "Transportation", "Business"]

# Change back to parent directory for saving results
os.chdir('..')
# Out:
# Loading data...
# Grids shape: (500000, 7, 7)
# Ratings shape: (500000, 4)
# Available ratings per advisor: [5000 5000 5000 5000]

# %%
# Reload the oracle module to get the latest changes
import importlib
import sys
if 'oracle' in sys.modules:
    importlib.reload(sys.modules['oracle'])
from oracle import WellnessOracle

# Initialize Wellness Oracle
wellness_oracle = WellnessOracle()
print("Tax Oracle initialized!")

# Select grids and ratings for Wellness advisor (not nan, index 0)
wellness_index = 0
grids_subset = grids[~np.isnan(ratings[:, wellness_index])]
ratings_subset = ratings[~np.isnan(ratings[:, wellness_index]), wellness_index]

# Get model scores
model_scores, train_data, test_data = wellness_oracle.fit_model(grids_subset, ratings_subset)
print("Model Scores:", model_scores)

predictions = wellness_oracle.predict(grids_subset)
print("Predictions shape:", predictions.shape)
# Out:
# Tax Oracle initialized!
#
# ==================================================
# Training AutoGluon model for Business Advisor
# ==================================================
# Available training samples: 5000
# Creating features...
# Creating features for Business Advisor...
# Creating basic features...
# Creating spatial features...
# Creating interaction features...
# Creating economic features...
# Total features created: 100
#   - Basic: 54
#   - Spatial: 27
#   - Interaction: 15
#   - Economic: 4
# Creating features for Business Advisor...
# Creating basic features...
# Creating spatial features...
# Creating interaction features...
# Creating economic features...
# Total features created: 100
#   - Basic: 54
#   - Spatial: 27
#   - Interaction: 15
#   - Economic: 4
# Creating features for Business Advisor...
# Creating basic features...
# Creating spatial features...
# Creating interaction features...
# No path specified. Models will be saved in: "AutogluonModels\ag-20251027_174944"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          12
# Memory Avail:       13.40 GB / 31.67 GB (42.3%)
# Disk Space Avail:   726.18 GB / 951.65 GB (76.3%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 45s of the 180s of remaining time (25%).
# Creating economic features...
# Total features created: 100
#   - Basic: 54
#   - Spatial: 27
#   - Interaction: 15
#   - Economic: 4
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-10-27 13:49:49,089	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8267
# 		Context path: "c:\Users\Lenovo\2156_cp2\AutogluonModels\ag-20251027_174944\ds_sub_fit\sub_fit_ho"
# (_dystack pid=23964) Running DyStack sub-fit ...
# (_dystack pid=23964) Failed to save metadata file due to exception 'NoneType' object has no attribute 'lower', skipping...
# (_dystack pid=23964) Beginning AutoGluon training ... Time limit = 36s
# (_dystack pid=23964) AutoGluon will save models to "c:\Users\Lenovo\2156_cp2\AutogluonModels\ag-20251027_174944\ds_sub_fit\sub_fit_ho"
# (_dystack pid=23964) Train Data Rows:    3555
# (_dystack pid=23964) Train Data Columns: 100
# (_dystack pid=23964) Label Column:       target
# (_dystack pid=23964) Problem Type:       regression
# (_dystack pid=23964) Preprocessing data ...
# (_dystack pid=23964) Using Feature Generators to preprocess the data ...
# (_dystack pid=23964) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=23964) 	Available Memory:                    13227.16 MB
# (_dystack pid=23964) 	Train Data (Original)  Memory Usage: 2.71 MB (0.0% of available memory)
# (_dystack pid=23964) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=23964) 	Stage 1 Generators:
# (_dystack pid=23964) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=23964) 	Stage 2 Generators:
# (_dystack pid=23964) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=23964) 	Stage 3 Generators:
# (_dystack pid=23964) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=23964) 	Stage 4 Generators:
# (_dystack pid=23964) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=23964) 	Stage 5 Generators:
# (_dystack pid=23964) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=23964) 	Unused Original Features (Count: 5): ['81', '86', '90', '93', '95']
# (_dystack pid=23964) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=23964) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=23964) 		These features do not need to be present at inference time.
# (_dystack pid=23964) 		('float', []) : 5 | ['81', '86', '90', '93', '95']
# (_dystack pid=23964) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=23964) 		('float', []) : 95 | ['0', '1', '2', '3', '4', ...]
# (_dystack pid=23964) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=23964) 		('float', []) : 95 | ['0', '1', '2', '3', '4', ...]
# (_dystack pid=23964) 	1.9s = Fit runtime
# (_dystack pid=23964) 	95 features in original data used to generate 95 features in processed data.
# (_dystack pid=23964) 	Train Data (Processed) Memory Usage: 2.58 MB (0.0% of available memory)
# (_dystack pid=23964) Data preprocessing and feature engineering runtime = 1.95s ...
# (_dystack pid=23964) AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# (_dystack pid=23964) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=23964) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=23964) User-specified model hyperparameters to be fit:
# (_dystack pid=23964) {
# (_dystack pid=23964) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=23964) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=23964) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=23964) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=23964) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=23964) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=23964) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=23964) }
# (_dystack pid=23964) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=23964) Fitting 106 L1 models, fit_strategy="sequential" ...
# (_dystack pid=23964) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 22.81s of the 34.22s of remaining time.
# (_dystack pid=23964) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# (_ray_fit pid=24068) [1000]	valid_set's l2: 0.0195242	valid_set's r2: 0.784085
# (_dystack pid=23964) 	0.7924	 = Validation score   (r2)
# (_dystack pid=23964) 	9.86s	 = Training   runtime
# (_dystack pid=23964) 	0.35s	 = Validation runtime
# (_dystack pid=23964) Fitting model: LightGBM_BAG_L1 ... Training model for up to 0.05s of the 11.46s of remaining time.
# (_dystack pid=23964) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# (_dystack pid=23964) 	Time limit exceeded... Skipping LightGBM_BAG_L1.
# (_ray_fit pid=31820) 	Warning: Model has no time left to train, skipping model... (Time Left = -0.0s)
# (_dystack pid=23964) Fitting model: WeightedEnsemble_L2 ... Training model for up to 34.23s of the 1.86s of remaining time.
# (_dystack pid=23964) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=23964) 	0.7924	 = Validation score   (r2)
# (_dystack pid=23964) 	0.0s	 = Training   runtime
# (_dystack pid=23964) 	0.0s	 = Validation runtime
# (_dystack pid=23964) Fitting 106 L2 models, fit_strategy="sequential" ...
# (_dystack pid=23964) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1.82s of the 1.77s of remaining time.
# (_dystack pid=23964) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# (_ray_fit pid=29136) 	Ran out of time, early stopping on iteration 142. Best iteration is:
# (_ray_fit pid=29136) 	[75]	valid_set's l2: 0.0201633	valid_set's r2: 0.761784
# (_dystack pid=23964) 	0.7947	 = Validation score   (r2)
# (_dystack pid=23964) 	2.87s	 = Training   runtime
# (_dystack pid=23964) 	0.08s	 = Validation runtime
# (_dystack pid=23964) Fitting model: WeightedEnsemble_L3 ... Training model for up to 34.23s of the -10.13s of remaining time.
# (_dystack pid=23964) 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.571, 'LightGBMXT_BAG_L1': 0.429}
# (_dystack pid=23964) 	0.7979	 = Validation score   (r2)
# (_dystack pid=23964) 	0.06s	 = Training   runtime
# (_dystack pid=23964) 	0.0s	 = Validation runtime
# (_dystack pid=23964) AutoGluon training complete, total runtime = 46.42s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1044.0 rows/s (445 batch size)
# (_dystack pid=23964) Failed to save metadata file due to exception 'NoneType' object has no attribute 'lower', skipping...
# (_dystack pid=23964) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\Lenovo\2156_cp2\AutogluonModels\ag-20251027_174944\ds_sub_fit\sub_fit_ho")
# (_dystack pid=23964) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                  model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0    LightGBMXT_BAG_L2       0.756046   0.794709          r2        1.361219       0.425994  12.730633                 0.359337                0.076238           2.868245            2       True          3
# 1  WeightedEnsemble_L3       0.752505   0.797853          r2        1.384108       0.428015  12.786344                 0.022889                0.002021           0.055710            3       True          4
# 2    LightGBMXT_BAG_L1       0.740998   0.792378          r2        1.001882       0.349756   9.862388                 1.001882                0.349756           9.862388            1       True          1
# 3  WeightedEnsemble_L2       0.740998   0.792378          r2        1.025156       0.350760   9.866146                 0.023274                0.001004           0.003758            2       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	62s	 = DyStack   runtime |	118s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Failed to save metadata file due to exception 'NoneType' object has no attribute 'lower', skipping...
# Beginning AutoGluon training ... Time limit = 118s
# AutoGluon will save models to "c:\Users\Lenovo\2156_cp2\AutogluonModels\ag-20251027_174944"
# Train Data Rows:    4000
# Train Data Columns: 100
# Label Column:       target
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    13027.22 MB
# 	Train Data (Original)  Memory Usage: 3.05 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 5): ['81', '86', '90', '93', '95']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 5 | ['81', '86', '90', '93', '95']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 95 | ['0', '1', '2', '3', '4', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 95 | ['0', '1', '2', '3', '4', ...]
# 	1.1s = Fit runtime
# 	95 features in original data used to generate 95 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.90 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 77.67s of the 116.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	0.7906	 = Validation score   (r2)
# 	8.13s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 57.83s of the 96.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.7958	 = Validation score   (r2)
# 	41.55s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 7.87s of the 46.72s of remaining time.
# 	0.7281	 = Validation score   (r2)
# 	13.5s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 116.54s of the 32.57s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.583, 'LightGBMXT_BAG_L1': 0.417}
# 	0.8009	 = Validation score   (r2)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 32.48s of the 32.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8004	 = Validation score   (r2)
# 	7.4s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 17.06s of the 17.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.7978	 = Validation score   (r2)
# 	6.28s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1.23s of the 1.20s of remaining time.
# 	0.7957	 = Validation score   (r2)
# 	18.15s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 116.54s of the -17.59s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.545, 'LightGBM_BAG_L2': 0.273, 'RandomForestMSE_BAG_L2': 0.182}
# 	0.8024	 = Validation score   (r2)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 135.35s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 378.2 rows/s (500 batch size)
# Failed to save metadata file due to exception 'NoneType' object has no attribute 'lower', skipping...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\Lenovo\2156_cp2\AutogluonModels\ag-20251027_174944")
# Model Scores: 0.80335760052919
# Creating features for all 5000 grids...
# Creating features for Business Advisor...
# Creating basic features...
# Creating spatial features...
# Creating interaction features...
# Creating economic features...
# Total features created: 100
#   - Basic: 54
#   - Spatial: 27
#   - Interaction: 15
#   - Economic: 4
# Making predictions with AutoGluon model...
# Predictions shape: (5000,)

# %%
from sklearn.metrics import r2_score
from matplotlib import pyplot as plt

def plot_and_r2(preds_train, preds_test, ratings_train, ratings_test):
    #Create scatter plot
    plt.figure(figsize=(10,6))
    plt.scatter(ratings_train, preds_train, label='Train Set Preds', s=15, c="#BBBBBB", alpha=0.6) #train set in gray
    plt.scatter(ratings_test, preds_test, label='Test Set Preds', s=20, c="#DC267F", alpha=0.8) #test set in magenta
    plt.plot([0,1], [0,1], label="Perfect Prediction", linewidth=2, c="k", linestyle='--') #target line in black

    #Set axis labels and title
    plt.xlabel("Actual Rating")
    plt.ylabel("Predicted Rating")
    plt.title("Wellness Oracle Predictions")

    #Turn off top and right spines
    ax = plt.gca()
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    plt.legend() #Display legend
    plt.grid(True, alpha=0.3)
    plt.show() #Show plot

    #Calculate R2 score for train and test sets
    train_r2 = r2_score(ratings_train, preds_train)
    test_r2 = r2_score(ratings_test, preds_test)
    
    print(f"Wellness Oracle Train Set R² score: {train_r2:.4f}")
    print(f"Wellness Oracle Test Set R² score: {test_r2:.4f}")
    
    return train_r2, test_r2

# Extract the actual ratings from train and test data
ratings_train = train_data['target'].values
ratings_test = test_data['target'].values

# Remove the target column to get just the features for prediction
train_features = train_data.drop('target', axis=1)
test_features = test_data.drop('target', axis=1)

# Make predictions on the train and test features
print("Making predictions on train set...")
preds_train = wellness_oracle.model.predict(train_features)

print("Making predictions on test set...")
preds_test = wellness_oracle.model.predict(test_features)

# Create the plot and get R² scores
train_r2, test_r2 = plot_and_r2(preds_train, preds_test, ratings_train, ratings_test)

# Additional analysis
print(f"\nModel Performance Summary:")
print(f"{'='*40}")
print(f"Training R²:   {train_r2:.4f}")
print(f"Test R²:       {test_r2:.4f}")
print(f"Overfitting:   {'Yes' if (train_r2 - test_r2) > 0.1 else 'No'} ({train_r2 - test_r2:.4f})")
print(f"Performance:   {'Excellent' if test_r2 > 0.9 else 'Good' if test_r2 > 0.8 else 'Fair' if test_r2 > 0.6 else 'Poor'}")
# Out:
# Making predictions on train set...
# Making predictions on test set...
# Wellness Oracle Train Set R² score: 0.9824
# Wellness Oracle Test Set R² score: 0.8034
#
# Model Performance Summary:
# ========================================
# Training R²:   0.9824
# Test R²:       0.8034
# Overfitting:   Yes (0.1791)
# Performance:   Good

# %%
# save model in pkl file
wellness_oracle.save_model('wellness_oracle_model.pkl')

# --- IGNORE ---
# instructions on how to use exported model
# from oracle import WellnessOracle
# wellness_oracle = WellnessOracle.load_model("wellness_oracle_model.pkl")
# --- IGNORE ---
